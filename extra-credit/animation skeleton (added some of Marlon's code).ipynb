# %% [markdown]
# ## importing our packages NOT per usual,
#
# - can't do normal "inline", must say "notebook". animation won't work without it, regardless of whether we figure out the other stuff.
# - also, we're using FuncAnimation from matplotlib to make our animation (check https://matplotlib.org/stable/api/animation_api.html)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np

# %% [markdown]
# #defining our array
# x = np.linspace(0,2*np.pi,100)
# #print(x[-1],2*np.pi)
#
#
#
# y = np.cos(x)
# z = np.cos(x) #but this needs to be the error actually

# %% [markdown]
# <u><i>note from AJ:</u> we have subplots because we need to have two panels.

# %%
#instead of the fig blah blah
#we call subplots so we can get multiple panels
#we did this in class!
x_data=[]
y_data=[]


f, axarr = plt.subplots(1,2)
line, = plt.plot([], []) #nothing to see here! (yet)

#x = np.linspace(0,1.75, 10)
#func = np.cos(x)


#left panel
axarr[0].plot(x,y)
axarr[0].set_xlabel('x')
axarr[0].set_ylabel('(f(x))')
axarr[0].set_title(r'Monte Carlo Integration')
axarr[0].set_xlim()
axarr[0].set_ylim()

#right panel
axarr[1].plot(x,z)
axarr[1].set_xlabel('x')
axarr[1].set_ylabel('cos(x)')
axarr[1].set_title(r'Error')
axarr[1].set_xlim()
axarr[1].set_ylim()

#add more space between the figures
f.subplots_adjust(wspace=0.4)
#fix the axis ratio
#here are two possible options
axarr[0].set_aspect('equal')    #make the ratio of the tick units equal, a bit counter intutitive
axarr[1].set_aspect(np.pi)


#need to call a function for FuncAnimation to animate
#but in this case the thing we want animated is the dots
def monte_animation(frame):
    #but what do we want to move? the dots. not the line. 
    x_data.append(i*10) #next couple of lines Marlon's
    y_data.append(i)
    
    
    line.set_xdata(x_data)
    line.set_ydata(y_data)
    return line,
    
    
    #these would be the x and y values that would be graphed 
    
#this is creating the animation
anim = FuncAnimation(fig, monte_animation, frames=len(x), interval=25, repeat=True)
#interval will need to be shorter, but keeping it 119 for the lolz for now 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-51fc4d9be018> in <module>
#      14
#      15 #left panel
# ---> 16 axarr[0].plot(x,y)
#      17 axarr[0].set_xlabel('x')
#      18 axarr[0].set_ylabel('(f(x))')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# ...

# %%
#uhhhh

# %%
fig = plt.figure() #as per usual. this is our figure size
#kept getting errors when saying "fig = plt.figure(figsize(7,7))" so i
#just took it out... yeah i'm unsure
line, = plt.plot([], []) #nothing to see here! (yet)

x = np.linspace(0,1.75, 10)
func = np.cos(x)

#need to call a function for FuncAnimation to animate
#but in this case the thing we want animated is the dots
def monte_animation(frame):
    #but what do we want to move? the dots. not the line. 
    x.append(frame)
    line.set_data(x,y
    return line,
    #color if under the cruve
    #color if over the curve
    
    
    #these would be the x and y values that would be graphed 
    
#this is creating the animation
anim = FuncAnimation(fig, monte_animation, frames=len(x), interval=25, repeat=True)
#interval will need to be shorter, but keeping it 119 for the lolz for now 
plt.show()
# Out:
#   File "<ipython-input-1-57cca52aa80f>", line 15
#     return line,
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# <u>note:</u> animation skeleton is not ready to run
