# %% [markdown]
# # Final Project: Monte Carlo Integration

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# ## Define a function for taking an integral

# %%
def func(x):
    return np.sin(x)

# %% [markdown]
# ## Setting perameters for the integration:
#
# n = 1000 number of samples for iteration

# %%
n = 10000

# %% [markdown]
# ## Random uniformally distributed number sets

# %%
#random uniform sets of numbers 
x = np.random.uniform(a,b,n) 
y = np.random.uniform(c,d,n)
z = 0*np.ones(n) 

a = -3*np.pi         #a = lower bound of integration x-axis

b = 3*np.pi          #b = upper bound of integration x-axis

d = max(f(x))        #d = upper bound wrt the y-axis
                
c = min(f(x))        #c = lower bound wrt the y-axis

# %% [markdown]
# ## Samples inside the curve and outside

# %%
#definate integral of z will always be = 0 
if i in range(len(z)):
    z(i) = (x(a),x(b))
              
integral = 0

for i in range (n):
    integral += rL
    
#ahhhhhh i cant get it
# Out:
#   File "/var/folders/g6/vtyfqk5s09d98k357hcpy5vw0000gn/T/ipykernel_21562/3125317202.py", line 2
#     def u: len(func(x))>len(z)
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## plot the samples and our line... (hopefully)

# %%
fig = plt.figure(figsize=(7,7))

plt.xlim([a,b])
plt.ylim([c,d])


plt.plot(x[pr],y[pr],'.',color="blue")

#plotting a sin curve 

k = np.linspace(a,b,n)

f_x= k
f_y= func(k)

plt.plot(f_x,f_y,color="green")

#plotting the y=0

z_y=z*0
plt.plot(x,z_y,color="black")

# %% [markdown]
# plt.plot(x[pr],y[pr],'.',color="")
#
# plt.plot(x[ur],y[ur],'.',color="")
# plt.plot(x[nr],y[nr],'.',color="")
#
#
# ur = np.where((y)>=func(x)) [0] #outside
# nr = np.where((y)<z*0) [0]

# %% [markdown]
# ## Report the result of the line
#
# i really have zero clue here.... here is my best guess on this... so... the area under the line lets say we r looking here at from (-1,1) lets just say...

# %%
line_approx = 4*(len(ir)/float(n) #marlon ty XD

error_line = (line_approx-(.5*2))/(.5*2)

print("number of samples =", n)
print("approximate area under function = ", line_approx)
print("Error in approx = ", error_line)
# Out:
#   File "/var/folders/g6/vtyfqk5s09d98k357hcpy5vw0000gn/T/ipykernel_21562/3890854233.py", line 3
#     error_line = (line_approx-(.5*2))/(.5*2)
#     ^
# SyntaxError: invalid syntax
